# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
import matplotlib as mpl
from sklearn.linear_model import Ridge
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import copy

import scipy.spatial.distance as spd
import ResidualDecomposition as RD

np.random.seed(0)

# %%
data = pd.read_csv("Datasets/P_BostonHousing.csv") 
X = data.iloc[:,:-1].values
Y = data.iloc[:,-1].values

# %%
# runtimes_monte_carlo = []
# starting_N = 2
# N = X.shape[0]
# permutation = np.random.permutation(np.arange(0, N))
# lr = Ridge()

# for i in range(5, N, 3):
#     permutation = np.random.permutation(permutation)
#     X_sub = X[permutation][:i]
#     Y_sub = Y[permutation][:i]
    
#     t1 = time.time()
#     rdshap = RD.ResidualDecompositionSymmetricStopping()
#     rdshap.fit(X_sub, Y_sub, lr)
#     t2 = time.time()
    
#     runtimes_monte_carlo.append((t2 - t1))
#     print("Runtime of {} samples is {}".format(i, t2-t1))
    
# np.savetxt("Data/runtimes_monte_carlo.csv", runtimes_monte_carlo, delimiter=',')

# %%
# runtimes_influence = []
# starting_N = 2
# N = X.shape[0]
# np.savetxt("Data/runtimes_all_S_influence.csv", runtimes_influence, delimiter=',')
# permutation = np.random.permutation(np.arange(0, N))
# lr = Ridge()

# for i in range(5, N, 3):
#     permutation = np.random.permutation(permutation)
#     X_sub = X[permutation][:i]
#     Y_sub = Y[permutation][:i]
    
#     t1 = time.time()
#     rdshap = RD.ResidualDecompositionSymmetricInfluenceFunctionLinear(X_sub, Y_sub, lr)
#     rdshap.All_S_Influence(15000)
#     t2 = time.time()
    
#     runtimes_influence.append((t2 - t1))
#     print("Runtime of {} samples is {}".format(i, t2-t1))
    
# np.savetxt("Data/runtimes_all_S_influence.csv", runtimes_influence, delimiter=',')

# %%
# runtimes_influence_largest = []
# starting_N = 2
# N = X.shape[0]
# permutation = np.random.permutation(np.arange(0, N))
# lr = Ridge()

# for i in range(5, N, 3):
#     permutation = np.random.permutation(permutation)
#     X_sub = X[permutation][:i]
#     Y_sub = Y[permutation][:i]
    
#     t1 = time.time()
#     rdshap = RD.ResidualDecompositionSymmetricInfluenceFunctionLinear(X_sub, Y_sub, lr)
#     rdshap.Largest_S_Influence(100)
#     t2 = time.time()
    
#     runtimes_influence_largest.append((t2 - t1))
#     print("Runtime of {} samples is {}".format(i, t2-t1))
    
# np.savetxt("Data/runtimes_largest_S_influence.csv", runtimes_influence, delimiter=',')

# %%
runtimes_kshap = []
starting_N = 2
N = X.shape[0]
permutation = np.random.permutation(np.arange(0, N))
lr = Ridge()

for i in range(5, N, 3):
    permutation = np.random.permutation(permutation)
    X_sub = X[permutation][:i]
    Y_sub = Y[permutation][:i]
    
    t1 = time.time()
    rdshap = RD.residual_shap_WLSN(X, Y, lr, D=10000)
    t2 = time.time()
    
    runtimes_kshap.append((t2 - t1))
    print("Runtime of {} samples is {}".format(i, t2-t1))
    
np.savetxt("Data/runtimes_kshap.csv", runtimes_kshap, delimiter=',')
# Out:
# Runtime of 5 samples is 5.320002555847168
# Runtime of 8 samples is 5.072712659835815
# Runtime of 11 samples is 5.0677666664123535
# Runtime of 14 samples is 5.173095464706421
# Runtime of 17 samples is 5.079017877578735
# Runtime of 20 samples is 5.2186362743377686
# Runtime of 23 samples is 5.130228042602539
# Runtime of 26 samples is 4.8258750438690186
# Runtime of 29 samples is 4.813933849334717
# Runtime of 32 samples is 4.847349166870117
# Runtime of 35 samples is 4.835745334625244
# Runtime of 38 samples is 4.8650267124176025
# Runtime of 41 samples is 4.873413562774658
# Runtime of 44 samples is 4.89426326751709
# Runtime of 47 samples is 4.979281902313232
# Runtime of 50 samples is 5.051990985870361
# Runtime of 53 samples is 4.9873127937316895
# Runtime of 56 samples is 4.962195873260498
# Runtime of 59 samples is 4.908921241760254
# Runtime of 62 samples is 4.93088436126709
# Runtime of 65 samples is 5.011384725570679
# Runtime of 68 samples is 4.95809268951416
# Runtime of 71 samples is 4.985673189163208
# Runtime of 74 samples is 4.990231990814209
# Runtime of 77 samples is 4.9242942333221436
# Runtime of 80 samples is 4.942167282104492
# Runtime of 83 samples is 4.9728357791900635
# Runtime of 86 samples is 4.960475921630859
# Runtime of 89 samples is 4.943308591842651
# Runtime of 92 samples is 4.954303026199341
# Runtime of 95 samples is 5.11650276184082
# Runtime of 98 samples is 5.10754132270813
# Runtime of 101 samples is 5.0853307247161865
# Runtime of 104 samples is 5.135371446609497
# Runtime of 107 samples is 5.124051809310913
# Runtime of 110 samples is 5.06015682220459
# Runtime of 113 samples is 5.075552463531494
# Runtime of 116 samples is 5.050836563110352
# Runtime of 119 samples is 5.035958528518677
# Runtime of 122 samples is 5.088718891143799
# Runtime of 125 samples is 5.146287441253662
# Runtime of 128 samples is 5.0280821323394775
# Runtime of 131 samples is 5.002814054489136
# Runtime of 134 samples is 4.995791673660278
# Runtime of 137 samples is 4.9967827796936035
# Runtime of 140 samples is 5.017988681793213
# Runtime of 143 samples is 5.016298532485962
# Runtime of 146 samples is 5.038674354553223
# Runtime of 149 samples is 5.023455619812012
# Runtime of 152 samples is 5.0594868659973145
# Runtime of 155 samples is 5.126871347427368
# Runtime of 158 samples is 5.094331502914429
# Runtime of 161 samples is 5.244956970214844
# Runtime of 164 samples is 5.206340312957764
# Runtime of 167 samples is 5.143681526184082
# Runtime of 170 samples is 5.147838354110718
# Runtime of 173 samples is 5.1669111251831055
# Runtime of 176 samples is 5.17066502571106
# Runtime of 179 samples is 5.1529459953308105
# Runtime of 182 samples is 5.180017948150635
# Runtime of 185 samples is 5.1660850048065186
# Runtime of 188 samples is 5.1935882568359375
# Runtime of 191 samples is 5.204031944274902
# Runtime of 194 samples is 5.173150300979614
# Runtime of 197 samples is 5.1790406703948975
# Runtime of 200 samples is 5.220992565155029
# Runtime of 203 samples is 5.149141073226929
# Runtime of 206 samples is 5.22529673576355
# Runtime of 209 samples is 5.18663763999939
# Runtime of 212 samples is 5.164000511169434
# Runtime of 215 samples is 5.162747383117676
# Runtime of 218 samples is 5.187438249588013
# Runtime of 221 samples is 5.2758002281188965
# Runtime of 224 samples is 5.208073616027832
# Runtime of 227 samples is 5.234918594360352
# Runtime of 230 samples is 5.151366472244263
# Runtime of 233 samples is 5.156056642532349
# Runtime of 236 samples is 5.180060148239136
# Runtime of 239 samples is 5.209214448928833
# Runtime of 242 samples is 5.145867586135864
# Runtime of 245 samples is 5.163076639175415
# Runtime of 248 samples is 5.176524877548218
# Runtime of 251 samples is 5.162190675735474
# Runtime of 254 samples is 5.188928127288818
# Runtime of 257 samples is 5.2112135887146
# Runtime of 260 samples is 5.200558662414551
# Runtime of 263 samples is 5.193174123764038
# Runtime of 266 samples is 5.187670946121216
# Runtime of 269 samples is 5.169005632400513
# Runtime of 272 samples is 5.255235433578491
# Runtime of 275 samples is 5.238458633422852
# Runtime of 278 samples is 5.219054698944092
# Runtime of 281 samples is 5.1985156536102295
# Runtime of 284 samples is 5.23252272605896
# Runtime of 287 samples is 5.215421199798584
# Runtime of 290 samples is 5.210383892059326
# Runtime of 293 samples is 5.220167875289917
# Runtime of 296 samples is 5.247747898101807
# Runtime of 299 samples is 5.263538122177124
# Runtime of 302 samples is 5.230290651321411
# Runtime of 305 samples is 5.253620624542236
# Runtime of 308 samples is 5.329351425170898
# Runtime of 311 samples is 5.397085905075073
# Runtime of 314 samples is 5.317241668701172
# Runtime of 317 samples is 5.27779221534729
# Runtime of 320 samples is 5.277374744415283
# Runtime of 323 samples is 5.260002851486206
# Runtime of 326 samples is 5.338854074478149
# Runtime of 329 samples is 5.275759696960449
# Runtime of 332 samples is 5.279308795928955
# Runtime of 335 samples is 5.250693321228027
# Runtime of 338 samples is 5.297616004943848
# Runtime of 341 samples is 5.267693281173706
# Runtime of 344 samples is 5.270233869552612
# Runtime of 347 samples is 5.311826229095459
# Runtime of 350 samples is 5.30356240272522
# Runtime of 353 samples is 5.273677349090576
# Runtime of 356 samples is 5.278117656707764
# Runtime of 359 samples is 5.295562982559204
# Runtime of 362 samples is 5.301394701004028
# Runtime of 365 samples is 5.238348007202148
# Runtime of 368 samples is 5.275792837142944
# Runtime of 371 samples is 5.266164779663086
# Runtime of 374 samples is 5.260871887207031
# Runtime of 377 samples is 5.300978660583496
# Runtime of 380 samples is 5.283205270767212
# Runtime of 383 samples is 5.332740306854248
# Runtime of 386 samples is 5.322051286697388
# Runtime of 389 samples is 5.259511709213257
# Runtime of 392 samples is 5.313030481338501
# Runtime of 395 samples is 5.261125802993774
# Runtime of 398 samples is 5.3443193435668945
# Runtime of 401 samples is 5.305734157562256
# Runtime of 404 samples is 5.269376993179321
# Runtime of 407 samples is 5.278501510620117
# Runtime of 410 samples is 5.280143976211548
# Runtime of 413 samples is 5.254393815994263
# Runtime of 416 samples is 5.274744272232056
# Runtime of 419 samples is 5.290295124053955
# Runtime of 422 samples is 5.312702655792236
# Runtime of 425 samples is 5.336153984069824
# Runtime of 428 samples is 5.278992414474487
# Runtime of 431 samples is 5.260230779647827
# Runtime of 434 samples is 5.282078742980957
# Runtime of 437 samples is 5.264289140701294
# Runtime of 440 samples is 5.282029390335083
# Runtime of 443 samples is 5.243839263916016
# Runtime of 446 samples is 5.261699199676514
# Runtime of 449 samples is 5.269672393798828
# Runtime of 452 samples is 5.251620531082153
# Runtime of 455 samples is 5.260534763336182
# Runtime of 458 samples is 5.277211427688599
# Runtime of 461 samples is 5.284238338470459
# Runtime of 464 samples is 5.269792795181274
# Runtime of 467 samples is 5.281225681304932
# Runtime of 470 samples is 5.307486534118652
# Runtime of 473 samples is 5.302132844924927
# Runtime of 476 samples is 5.296962738037109
# Runtime of 479 samples is 5.27929425239563
# Runtime of 482 samples is 5.312947034835815
# Runtime of 485 samples is 5.309316396713257
# Runtime of 488 samples is 5.286763429641724
# Runtime of 491 samples is 5.287335395812988
# Runtime of 494 samples is 5.2703118324279785
# Runtime of 497 samples is 5.285757064819336
# Runtime of 500 samples is 5.271510124206543
# Runtime of 503 samples is 5.34786581993103

# %%
runtimes_influence = np.genfromtxt("Data/runtimes_all_S_influence.csv", delimiter=',')
runtimes_monte_carlo = np.genfromtxt("Data/runtimes_monte_carlo.csv", delimiter=',')
runtimes_influence_largest = np.genfromtxt("Data/runtimes_largest_S_influence.csv", delimiter=',')
runtimes_kshap = np.genfromtxt("Data/runtimes_kshap.csv", delimiter=',')

# %%
plt.plot(list(range(5, N, 3)), np.log10(runtimes_influence), label="All S")
plt.plot(list(range(5, N, 3)), np.log10(runtimes_monte_carlo), label='Monte Carlo')
plt.plot(list(range(5, N, 3)), np.log10(runtimes_kshap), label='KernelShapley')
plt.plot(list(range(5, N, 3)), np.log10(runtimes_influence_largest), label='Largest S')
plt.xlabel("Number of samples in data")
plt.ylabel("Runtime (log10 Seconds)")

plt.annotate(" {}s".format(np.round(runtimes_influence_largest[-1], 2)), (503, np.log10(runtimes_influence_largest[-1])))
plt.annotate(" {}s".format(np.round(runtimes_kshap[-1], 2)), (503, np.log10(runtimes_kshap[-1])))
plt.annotate(" {}s".format(np.round(runtimes_monte_carlo[-1], 2)), (503, np.log10(runtimes_monte_carlo[-1])))
plt.annotate(" {}s".format(np.round(runtimes_influence[-1], 2)), (503, np.log10(runtimes_influence[-1])))

plt.xlim([0, 503])
plt.legend()
